# %% [markdown]
# # Week 2 proof of life
# CML3112. Set STUDENT_ID to your Student Registration Number, including slashes (fictional example only: 99/TEST/000/DEMO-X). Run cells in order.

# %%
STUDENT_ID = "23/631/BARC-S"
COHORT = "CML3112"

# %%
print("Hello from CML3112")
proof_sum = 2 + 2
print(proof_sum)
# Out:
# Hello from CML3112
# 4
# Hello from CML3112
# 4

# %%
readings = 12

# %%
readings = readings + 5
print(readings)
# Out:
# 17
# 17

# %% [markdown]
# Run the previous cell three times. Explain the changing result below, then restart and run all.

# %% [markdown]
# My explanation: In my first execution, the reading increased from 12 to 17, the second execution resulted in 22 and the third gave 27 .this happens because the cell adds 5 to the current readings value and then stores the updated value. the notebook keeps this updated value in memory, meaning each new run continues from where the previous one stopped . when the restart and run all is selected , the stored value is erased and the cell starts fresh at 12 resulting in 17

# %%
import csv
with open("site_inspection_log.csv", newline="") as f:
    rows = list(csv.DictReader(f))
print(len(rows))
# Out:
# 4
# 4

# %% [markdown]
# After Restart and Run All, expected outputs include 4, 17 and 4 rows. Save with slashes replaced by underscores in the filename only, for example 99_TEST_000_DEMO-X_W02.ipynb.
